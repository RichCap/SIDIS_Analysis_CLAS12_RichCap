# %%
# %reset -f
import ROOT
import re
# import numpy
import traceback

# import math
# import array
# import copy

from MyCommonAnalysisFunction_richcap import      Bin_Definition_Array, color
from Binning_Dictionaries             import Full_Bin_Definition_Array


def Compare_Arrays(bin_key, primary___array=Full_Bin_Definition_Array, secondary_array=Bin_Definition_Array):
    default_val_1 = primary___array.get(bin_key, None)
    default_val_2 = secondary_array.get(bin_key, None)
    if(default_val_1 == None):
        for ii in primary___array:
            if((bin_key in ii) and all(f"{bin_key}{jj}" != ii for jj in range(0, 10))):
                print(f"{color.Error}Needed to grab '{ii}' instead of '{bin_key}' from the 'primary___array'{color.END}")
                default_val_1 = primary___array[ii]
                break
    if(default_val_2 == None):
        for ii in secondary_array:
            if((bin_key in ii) and all(f"{bin_key}{jj}" != ii for jj in range(0, 10))):
                print(f"{color.Error}Needed to grab '{ii}' instead of '{bin_key}' from the 'secondary_array'{color.END}")
                default_val_2 = primary___array[ii]
                break
    return default_val_1, default_val_2
                

change_log = ""
def update_change_log(Q2y_Bin, zpTBin, log_input=change_log, z_max=None, z_min=None, pTmax=None, pTmin=None):
    log = f"For Q2-y Bin {Q2y_Bin} — z-pT Bin {zpTBin}, changed:\n"
    if(z_max != None):
        log = f"{log}\t(*) z_max to {z_max}\n"
    if(z_min != None):
        log = f"{log}\t(*) z_min to {z_min}\n"
    if(pTmax != None):
        log = f"{log}\t(*) pTmax to {pTmax}\n"
    if(pTmin != None):
        log = f"{log}\t(*) pTmin to {pTmin}\n"
    if("(*)" not in log):
        return log_input
    if(log not in log_input):
        log_input = f"{log_input}\n{log}"
    return log_input

def change_arrays(z_max_In, z_min_In, pTmax_In, pTmin_In, z_max_New=None, z_min_New=None, pTmax_New=None, pTmin_New=None):
    z_max = z_max_New if(z_max_New != None) else z_max_In
    z_min = z_min_New if(z_min_New != None) else z_min_In
    pTmax = pTmax_New if(pTmax_New != None) else pTmax_In
    pTmin = pTmin_New if(pTmin_New != None) else pTmin_In
    return [z_max, z_min, pTmax, pTmin]




_CHANGE_LOG_BLOCK_RE = re.compile(r"For Q2-y Bin (\d+)\s*[—\-]\s*z-pT Bin (\d+), changed:\n"
                                  r"((?:\t\(\*\)[^\n]*\n?)*)")
_CHANGE_LOG_FIELD_RE = re.compile(r"\(\*\)\s*(z_max|z_min|pTmax|pTmin)\s+to\s+([-+]?\d*\.?\d+(?:[eE][-+]?\d+)?)")

def apply_change_log(log_text, primary_array=Full_Bin_Definition_Array, secondary_array=Bin_Definition_Array, verbose=True):
    # Replay a saved change_log string onto both bin-definition arrays
    # Force-applies every logged field update to BOTH arrays. If the two arrays differ for a restored key (before and/or after), print a warning with the before/after values for each array
    applied_keys = []
    missing_keys = []
    differ_keys = []
    if((not log_text) or (not str(log_text).strip())):
        if(verbose):
            print(f"{color.Error}apply_change_log: empty change_log — nothing to restore.{color.END}")
        return applied_keys
    for match in _CHANGE_LOG_BLOCK_RE.finditer(log_text):
        q2y, zpt, body = match.group(1), match.group(2), match.group(3)
        bin_key = f"Q2-y={q2y}, z-pT={zpt}"
        updates = {name: float(val) for name, val in _CHANGE_LOG_FIELD_RE.findall(body)}
        if(not updates):
            if(verbose):
                print(f"{color.Error}apply_change_log: no field updates parsed for {bin_key}{color.END}")
            continue
        # Compare_Arrays returns (primary=Full, secondary=Bin) by default
        val_full, val_bin = Compare_Arrays(bin_key, primary___array=primary_array, secondary_array=secondary_array,)
        if((val_full is None) or (val_bin is None)):
            missing_keys.append(bin_key)
            if(verbose):
                print(f"{color.Error}apply_change_log: missing key {bin_key} (Full={val_full}, Bin={val_bin}) — skipped.{color.END}")
            continue
        before_full = list(val_full)
        before_bin = list(val_bin)
        new_full = change_arrays(*before_full, z_max_New=updates.get("z_max"), z_min_New=updates.get("z_min"), pTmax_New=updates.get("pTmax"), pTmin_New=updates.get("pTmin"),)
        new_bin = change_arrays(*before_bin, z_max_New=updates.get("z_max"), z_min_New=updates.get("z_min"), pTmax_New=updates.get("pTmax"), pTmin_New=updates.get("pTmin"),)
        # Force-update both arrays with the logged field overrides
        primary_array[bin_key] = new_full
        secondary_array[bin_key] = new_bin
        applied_keys.append(bin_key)
        differed_before = before_bin != before_full
        differed_after = new_bin != new_full
        if(differed_before or differed_after):
            differ_keys.append(bin_key)
            if(verbose):
                print(f"{color.Error}WARNING: arrays differed for {bin_key} (forced update applied to both){color.END}\n\tBin_Definition_Array:      {before_bin}  -->  {new_bin}\n\tFull_Bin_Definition_Array: {before_full}  -->  {new_full}\n\tLogged updates: {updates}")
        elif(verbose):
            print(f"{color.BGREEN}Restored {bin_key}:{color.END} {before_bin}  -->  {new_bin}  (updates: {updates})")
    if(verbose):
        print(f"\n{color.BBLUE}apply_change_log summary:{color.END}\n\tRestored: {len(applied_keys)} bin(s)\n\tMissing:  {len(missing_keys)} bin(s)\n\tDiffered: {len(differ_keys)} bin(s) (see warnings above)")
        if(missing_keys):
            print(f"\tMissing keys: {missing_keys}")
    return applied_keys

print(f"\n{color.BBLUE}Ready to Run{color.END}\n")
# Out:
# Ready to Run

# %%
print(f"{color.BOLD}Total Num of Bins Defined in      {color.BBLUE}'Bin_Definition_Array'{color.END_B}: {color.UNDERLINE}{len(Bin_Definition_Array)}{color.END}")
print(f"{color.BOLD}Total Num of Bins Defined in {color.BBLUE}'Full_Bin_Definition_Array'{color.END_B}: {color.UNDERLINE}{len(Full_Bin_Definition_Array)}{color.END}\n\n")


# Q2_y_Bins = [4]
# z_pT_Bins = [1, 4]
# z_pT_Bins = list(range(1, 15))
Q2_y_Bins = [3]
z_pT_Bins = list(range(1, 7))
# z_pT_Bins = [14]


z_max = 0.68 # New for bin 1
z_max = 0.73 # New for bin 2, 3
z_max = None
z_min = None
pTmax = 0.98 # New for bin 1
pTmax = None
pTmin = None

for bin_key in Full_Bin_Definition_Array:
    if("Key" in bin_key):
        print(f"{color.BGREEN}{bin_key} --> {Full_Bin_Definition_Array[bin_key]}{color.END}")
        if("z-pT" in bin_key):
            print("")
    if(all(f"Q2-y={q2y}," not in bin_key for q2y in Q2_y_Bins) and (Q2_y_Bins != [])):
        continue
    if(("z-pT=" in bin_key) and any(q2y_only in z_pT_Bins for q2y_only in ["Q2_y_Only", "q2_y_only", "Q2y", "q2y"])):
        continue
    if((Q2_y_Bins != []) and (z_pT_Bins != [])):
        for q2y in Q2_y_Bins:
            skip = True
            if(f"Q2-y={q2y}" not in bin_key):
                skip = True
                continue
            for zpt in z_pT_Bins:
                if(f"Q2-y={q2y}, z-pT={zpt}" == bin_key):
                    skip = False
                    if(any(change != None for change in [z_max, z_min, pTmax, pTmin])):
                        val1, val2 = Compare_Arrays(bin_key)
                        z_max_1, z_min_1, pTmax_1, pTmin_1 = val1
                        z_max_2, z_min_2, pTmax_2, pTmin_2 = val2
                        Bin_Definition_Array[bin_key]      = change_arrays(z_max_1, z_min_1, pTmax_1, pTmin_1, z_max, z_min, pTmax, pTmin)
                        Full_Bin_Definition_Array[bin_key] = change_arrays(z_max_2, z_min_2, pTmax_2, pTmin_2, z_max, z_min, pTmax, pTmin)
                        change_log = update_change_log(q2y, zpt, change_log, z_max, z_min, pTmax, pTmin)
                    break
            if(not skip):
                break
        if(skip):
            continue
    val1, val2 = Compare_Arrays(bin_key, primary___array=Full_Bin_Definition_Array, secondary_array=Bin_Definition_Array)
    if(None not in [val1, val2]):
        print(f"\t{color.BBLUE}Bin_Definition_Array:      {color.END_B}{bin_key} -->{color.END} {val1}")
        print(f"\t{color.BBLUE}Full_Bin_Definition_Array: {color.END_B}{bin_key} -->{color.END} {val2}\n")
        
    
print(f"\n{color.BGREEN}Full List of Changes:{color.END}\n{change_log}\n")
# Out:
# Total Num of Bins Defined in      'Bin_Definition_Array': 547
# Total Num of Bins Defined in 'Full_Bin_Definition_Array': 508
#
#
# Key-Q2-y-Bins --> 'Q2-y=#, Q2-y'-> [Q2_max, Q2_min, y_max, y_min] for Q2-y Bin #
# Key-z-pT-Bins --> 'Q2-y=*, z-pT=#'-> [z_max, z_min, pT_max, pT_min] for z-pT Bin # in Q2-y Bin *
#
# 	Bin_Definition_Array:      Q2-y=3, z-pT=1 --> [0.73, 0.56, 0.2, 0.05]
# 	Full_Bin_Definition_Array: Q2-y=3, z-pT=1 --> [0.73, 0.56, 0.2, 0.05]
#
# 	Bin_Definition_Array:      Q2-y=3, z-pT=2 --> [0.73, 0.56, 0.3, 0.2]
# 	Full_Bin_Definition_Array: Q2-y=3, z-pT=2 --> [0.73, 0.56, 0.3, 0.2]
#
# 	Bin_Definition_Array:      Q2-y=3, z-pT=3 --> [0.73, 0.56, 0.39, 0.3]
# 	Full_Bin_Definition_Array: Q2-y=3, z-pT=3 --> [0.73, 0.56, 0.39, 0.3]
#
# 	Bin_Definition_Array:      Q2-y=3, z-pT=4 --> [0.73, 0.56, 0.49, 0.39]
# 	Full_Bin_Definition_Array: Q2-y=3, z-pT=4 --> [0.73, 0.56, 0.49, 0.39]
#
# 	Bin_Definition_Array:      Q2-y=3, z-pT=5 --> [0.73, 0.56, 0.59, 0.49]
# 	Full_Bin_Definition_Array: Q2-y=3, z-pT=5 --> [0.73, 0.56, 0.59, 0.49]
#
# 	Bin_Definition_Array:      Q2-y=3, z-pT=6 --> [0.73, 0.56, 0.76, 0.59]
# 	Full_Bin_Definition_Array: Q2-y=3, z-pT=6 --> [0.73, 0.56, 0.76, 0.59]
#
#
# Full List of Changes:
#
# For Q2-y Bin 1 — z-pT Bin 1, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 2, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 3, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 4, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 5, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 6, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 7, changed:
# 	(*) z_max to 0.68
# 	(*) pTmax to 0.98
#
# For Q2-y Bin 1 — z-pT Bin 14, changed:
# 	(*) pTmax to 0.98
#
# For Q2-y Bin 2 — z-pT Bin 1, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 2, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 3, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 4, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 5, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 6, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 1, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 2, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 3, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 4, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 5, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 6, changed:
# 	(*) z_max to 0.73

# %%
# change_log = '\nFor Q2-y Bin 1 — z-pT Bin 1, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 2, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 3, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 4, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 5, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 6, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 7, changed:\n\t(*) z_max to 0.68\n\t(*) pTmax to 0.98\n\nFor Q2-y Bin 1 — z-pT Bin 14, changed:\n\t(*) pTmax to 0.98\n\nFor Q2-y Bin 2 — z-pT Bin 1, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 2, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 3, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 4, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 5, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 6, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 1, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 2, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 3, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 4, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 5, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 6, changed:\n\t(*) z_max to 0.73\n'
# print(change_log)

# %%
change_log = '\nFor Q2-y Bin 1 — z-pT Bin 1, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 2, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 3, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 4, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 5, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 6, changed:\n\t(*) z_max to 0.68\n\nFor Q2-y Bin 1 — z-pT Bin 7, changed:\n\t(*) z_max to 0.68\n\t(*) pTmax to 0.98\n\nFor Q2-y Bin 1 — z-pT Bin 14, changed:\n\t(*) pTmax to 0.98\n\nFor Q2-y Bin 2 — z-pT Bin 1, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 2, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 3, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 4, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 5, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 2 — z-pT Bin 6, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 1, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 2, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 3, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 4, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 5, changed:\n\t(*) z_max to 0.73\n\nFor Q2-y Bin 3 — z-pT Bin 6, changed:\n\t(*) z_max to 0.73\n'
# print(change_log)

Full_Bin_Definition_Array_Copy = Full_Bin_Definition_Array
Bin_Definition_Array_Copy = Bin_Definition_Array

# Restore array updates from the saved change_log after a kernel restart.
print(f"{color.BBLUE}Restoring bin definitions from saved change_log...{color.END}")
applied = apply_change_log(change_log)
print(f"\n{color.BGREEN}Restored change_log contents:{color.END}\n{change_log}\n")
print(f"{color.BOLD}Tip:{color.END} After more Cell 1 edits, copy the new printed change_log back into this cell.")

Updated_Q_Full_Bin_Definition_Array = bool(Full_Bin_Definition_Array != Full_Bin_Definition_Array_Copy)
Updated_Q_Bin_Definition_Array      = bool(Bin_Definition_Array != Bin_Definition_Array_Copy)

print(f"Updated Full_Bin_Definition_Array? --> {color.BGREEN if(Updated_Q_Full_Bin_Definition_Array) else color.Error}{Updated_Q_Full_Bin_Definition_Array}{color.END}")
print(f"Updated Bin_Definition_Array?      --> {color.BGREEN if(Updated_Q_Bin_Definition_Array)      else color.Error}{Updated_Q_Bin_Definition_Array}{color.END}")
# Out:
# Restoring bin definitions from saved change_log...
# Restored Q2-y=1, z-pT=1: [0.68, 0.4, 0.22, 0.05]  -->  [0.68, 0.4, 0.22, 0.05]  (updates: {'z_max': 0.68})
# Restored Q2-y=1, z-pT=2: [0.68, 0.4, 0.32, 0.22]  -->  [0.68, 0.4, 0.32, 0.22]  (updates: {'z_max': 0.68})
# Restored Q2-y=1, z-pT=3: [0.68, 0.4, 0.42, 0.32]  -->  [0.68, 0.4, 0.42, 0.32]  (updates: {'z_max': 0.68})
# Restored Q2-y=1, z-pT=4: [0.68, 0.4, 0.52, 0.42]  -->  [0.68, 0.4, 0.52, 0.42]  (updates: {'z_max': 0.68})
# Restored Q2-y=1, z-pT=5: [0.68, 0.4, 0.63, 0.52]  -->  [0.68, 0.4, 0.63, 0.52]  (updates: {'z_max': 0.68})
# Restored Q2-y=1, z-pT=6: [0.68, 0.4, 0.75, 0.63]  -->  [0.68, 0.4, 0.75, 0.63]  (updates: {'z_max': 0.68})
# Restored Q2-y=1, z-pT=7: [0.68, 0.4, 0.98, 0.75]  -->  [0.68, 0.4, 0.98, 0.75]  (updates: {'z_max': 0.68, 'pTmax': 0.98})
# Restored Q2-y=1, z-pT=14: [0.4, 0.29, 0.98, 0.75]  -->  [0.4, 0.29, 0.98, 0.75]  (updates: {'pTmax': 0.98})
# Restored Q2-y=2, z-pT=1: [0.73, 0.5, 0.25, 0.05]  -->  [0.73, 0.5, 0.25, 0.05]  (updates: {'z_max': 0.73})
# Restored Q2-y=2, z-pT=2: [0.73, 0.5, 0.35, 0.25]  -->  [0.73, 0.5, 0.35, 0.25]  (updates: {'z_max': 0.73})
# Restored Q2-y=2, z-pT=3: [0.73, 0.5, 0.45, 0.35]  -->  [0.73, 0.5, 0.45, 0.35]  (updates: {'z_max': 0.73})
# Restored Q2-y=2, z-pT=4: [0.73, 0.5, 0.54, 0.45]  -->  [0.73, 0.5, 0.54, 0.45]  (updates: {'z_max': 0.73})
# Restored Q2-y=2, z-pT=5: [0.73, 0.5, 0.67, 0.54]  -->  [0.73, 0.5, 0.67, 0.54]  (updates: {'z_max': 0.73})
# Restored Q2-y=2, z-pT=6: [0.73, 0.5, 0.93, 0.67]  -->  [0.73, 0.5, 0.93, 0.67]  (updates: {'z_max': 0.73})
# Restored Q2-y=3, z-pT=1: [0.73, 0.56, 0.2, 0.05]  -->  [0.73, 0.56, 0.2, 0.05]  (updates: {'z_max': 0.73})
# Restored Q2-y=3, z-pT=2: [0.73, 0.56, 0.3, 0.2]  -->  [0.73, 0.56, 0.3, 0.2]  (updates: {'z_max': 0.73})
# Restored Q2-y=3, z-pT=3: [0.73, 0.56, 0.39, 0.3]  -->  [0.73, 0.56, 0.39, 0.3]  (updates: {'z_max': 0.73})
# Restored Q2-y=3, z-pT=4: [0.73, 0.56, 0.49, 0.39]  -->  [0.73, 0.56, 0.49, 0.39]  (updates: {'z_max': 0.73})
# Restored Q2-y=3, z-pT=5: [0.73, 0.56, 0.59, 0.49]  -->  [0.73, 0.56, 0.59, 0.49]  (updates: {'z_max': 0.73})
# Restored Q2-y=3, z-pT=6: [0.73, 0.56, 0.76, 0.59]  -->  [0.73, 0.56, 0.76, 0.59]  (updates: {'z_max': 0.73})
#
# apply_change_log summary:
# 	Restored: 20 bin(s)
# 	Missing:  0 bin(s)
# 	Differed: 0 bin(s) (see warnings above)
#
# Restored change_log contents:
#
# For Q2-y Bin 1 — z-pT Bin 1, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 2, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 3, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 4, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 5, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 6, changed:
# 	(*) z_max to 0.68
#
# For Q2-y Bin 1 — z-pT Bin 7, changed:
# 	(*) z_max to 0.68
# 	(*) pTmax to 0.98
#
# For Q2-y Bin 1 — z-pT Bin 14, changed:
# 	(*) pTmax to 0.98
#
# For Q2-y Bin 2 — z-pT Bin 1, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 2, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 3, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 4, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 5, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 2 — z-pT Bin 6, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 1, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 2, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 3, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 4, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 5, changed:
# 	(*) z_max to 0.73
#
# For Q2-y Bin 3 — z-pT Bin 6, changed:
# 	(*) z_max to 0.73
#
#
# Tip: After more Cell 1 edits, copy the new printed change_log back into this cell.
# Updated Full_Bin_Definition_Array? --> False
# Updated Bin_Definition_Array?      --> False
